# %%
import pandas as pd

titanic_df = pd.read_csv('titanic_train.csv')
titanic_df.head()
titanic_pclass = titanic_df['Pclass']
titanic_pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('house_raw.csv')
# data.head()
# data.describe()
# data.hist(bins=50, figsize=(20, 15))
X = data[data.columns[0:5]]
y = data[["house_value"]]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

from sklearn.preprocessing import MinMaxScaler
scaler_minmax = MinMaxScaler()
scaler_minmax.fit(X_train)
X_scaled_minmax_train = scaler_minmax.transform(X_train)
X_scaled_minmax_test = scaler_minmax.transform(X_test)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_scaled_minmax_train, y_train)

pred_train = model.predict(X_scaled_minmax_train)
a=model.score(X_scaled_minmax_train, y_train)
print("훈련데이터의 정확도 : ", a)

pred_test = model.predict(X_scaled_minmax_test)
b= model.score(X_scaled_minmax_test, y_test)
print("테스트 데이터의 정확도 : ", b)

#data.head()
#data.describe()

#data_bedroom = data[data['bedrooms']<0.6]
#data_bedroom['bedrooms'].hist(bins=100, figsize= (20, 15))

data_bedroom2 = data[data['bedrooms']>=0.6]
# print(data_bedroom2['bedrooms'].value_counts())
data_bedroom2
# Out:
# 훈련데이터의 정확도 :  0.5463729131516732
# 테스트 데이터의 정확도 :  -2.8220648010161544
#        housing_age  income  bedrooms  households     rooms  house_value
# 1732            43  1.3157  0.602489    2.133660  1.911826       333300
# 1911            25  1.7866  0.635258    3.566327  1.678571       325000
# 3162            26  1.4904  0.658869    3.750779  1.598131       275000
# 3165            12  1.2012  0.613084    3.271233  1.465753       275000
# 5446            24  1.8304  0.662539    3.973545  1.708995       225000
# 7674            45  1.4940  0.625887    3.673981  1.768025       187500
# 7677            20  1.0938  0.923077    1.739130  1.130435       187500
# 9658            46  2.8750  1.000000    1.846154  0.846154       162500
# 9716            16  0.5360  1.000000   18.444444  2.111111       162500
# 11810           37  2.7634  0.700000    4.524194  1.411290       137500
# 11827            4  2.3750  1.000000    3.000000  1.000000       137500
# ...

# %%
import pandas as pd
data_df = pd.read_csv("titanic_train.csv")
data_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
data_df = pd.read_csv("titanic_train.csv")

data_df_boolean = data_df.loc[data_df['Age']>60 & data_df['Pclass']>2, ['Name', 'Age']]

data_df_boolean

# data_df_count2 = pd.DataFrame(data_df_count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_88164/540995434.py in <module>
#       2 data_df = pd.read_csv("titanic_train.csv")
#       3
# ----> 4 data_df_boolean = data_df.loc[data_df['Age']>60 & data_df['Pclass']>2, ['Name', 'Age']]
#       5
#       6 data_df_boolean
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
